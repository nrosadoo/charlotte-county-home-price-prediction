# %% [markdown]
# # Data Exploration: Charlotte County Housing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/simulated_housing_data.csv')
df.head()
